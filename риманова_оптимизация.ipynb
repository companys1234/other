# %%
import numpy as np
from scipy.linalg import expm

def riemannian_gradient_sphere(f, x):
    """Риманов градиент на сфере"""
    euclidean_grad = np.array([1, 1, 1])  # ∇f = (1, 1, 1)
    return euclidean_grad - np.dot(x, euclidean_grad) * x

def exponential_map_sphere(x, v):
    """Экспоненциальное отображение на сфере"""
    norm_v = np.linalg.norm(v)
    if norm_v < 1e-10:
        return x
    return x * np.cos(norm_v) + (v / norm_v) * np.sin(norm_v)

def optimize_on_sphere(max_iter=100, step_size=0.1):
    x = np.array([1.0, 0.0, 0.0])  # Начальная точка
    for _ in range(max_iter):
        grad = riemannian_gradient_sphere(None, x)
        x = exponential_map_sphere(x, -step_size * grad)
        print(f"Точка: {x}, Норма: {np.linalg.norm(x):.4f}")
    return x

x_opt = optimize_on_sphere()
print("Оптимальная точка:", x_opt)
# Out:
# Точка: [ 0.99001666 -0.099667   -0.099667  ], Норма: 1.0000
# Точка: [ 0.95664911 -0.20593989 -0.20593989], Норма: 1.0000
# Точка: [ 0.89607877 -0.31388121 -0.31388121], Норма: 1.0000
# Точка: [ 0.80740552 -0.4171908  -0.4171908 ], Норма: 1.0000
# Точка: [ 0.69365954 -0.50933115 -0.50933115], Норма: 1.0000
# Точка: [ 0.56169135 -0.58502258 -0.58502258], Норма: 1.0000
# Точка: [ 0.42073816 -0.64147463 -0.64147463], Норма: 1.0000
# Точка: [ 0.28023535 -0.67877395 -0.67877395], Норма: 1.0000
# Точка: [ 0.14787062 -0.69933335 -0.69933335], Норма: 1.0000
# Точка: [ 0.02859824 -0.70681757 -0.70681757], Норма: 1.0000
# Точка: [-0.07532993 -0.70509765 -0.70509765], Норма: 1.0000
# Точка: [-0.16372355 -0.69756527 -0.69756527], Норма: 1.0000
# Точка: [-0.23766434 -0.68684629 -0.68684629], Норма: 1.0000
# Точка: [-0.29884728 -0.67479267 -0.67479267], Норма: 1.0000
# Точка: [-0.34913814 -0.66260945 -0.66260945], Норма: 1.0000
# Точка: [-0.39032332 -0.65101755 -0.65101755], Норма: 1.0000
# Точка: [-0.4239937  -0.64040196 -0.64040196], Норма: 1.0000
# Точка: [-0.45150848 -0.63092793 -0.63092793], Норма: 1.0000
# Точка: [-0.47400086 -0.62262476 -0.62262476], Норма: 1.0000
# Точка: [-0.49240218 -0.61544297 -0.61544297], Норма: 1.0000
# Точка: [-0.50747179 -0.60929155 -0.60929155], Норма: 1.0000
# Точка: [-0.51982634 -0.6040615  -0.6040615 ], Норма: 1.0000
# Точка: [-0.52996585 -0.59963997 -0.59963997], Норма: 1.0000
# Точка: [-0.53829587 -0.59591843 -0.59591843], Норма: 1.0000
# Точка: [-0.54514559 -0.59279688 -0.59279688], Норма: 1.0000
# Точка: [-0.55078268 -0.59018575 -0.59018575], Норма: 1.0000
# Точка: [-0.55542513 -0.58800635 -0.58800635], Норма: 1.0000
# Точка: [-0.55925081 -0.58619047 -0.58619047], Норма: 1.0000
# Точка: [-0.5624051  -0.58467962 -0.58467962], Норма: 1.0000
# Точка: [-0.56500699 -0.58342399 -0.58342399], Норма: 1.0000
# Точка: [-0.56715406 -0.58238144 -0.58238144], Норма: 1.0000
# Точка: [-0.56892637 -0.58151646 -0.58151646], Норма: 1.0000
# Точка: [-0.57038974 -0.58079925 -0.58079925], Норма: 1.0000
# Точка: [-0.57159829 -0.58020488 -0.58020488], Норма: 1.0000
# Точка: [-0.57259658 -0.5797125  -0.5797125 ], Норма: 1.0000
# Точка: [-0.57342133 -0.57930475 -0.57930475], Норма: 1.0000
# Точка: [-0.57410279 -0.57896718 -0.57896718], Норма: 1.0000
# Точка: [-0.57466592 -0.57868778 -0.57868778], Норма: 1.0000
# Точка: [-0.5751313  -0.57845656 -0.57845656], Норма: 1.0000
# Точка: [-0.57551594 -0.57826525 -0.57826525], Норма: 1.0000
# Точка: [-0.57583387 -0.57810698 -0.57810698], Норма: 1.0000
# Точка: [-0.57609666 -0.57797606 -0.57797606], Норма: 1.0000
# Точка: [-0.57631389 -0.57786776 -0.57786776], Норма: 1.0000
# Точка: [-0.57649346 -0.5777782  -0.5777782 ], Норма: 1.0000
# Точка: [-0.57664191 -0.57770412 -0.57770412], Норма: 1.0000
# Точка: [-0.57676463 -0.57764287 -0.57764287], Норма: 1.0000
# Точка: [-0.57686609 -0.57759221 -0.57759221], Норма: 1.0000
# Точка: [-0.57694996 -0.57755032 -0.57755032], Норма: 1.0000
# Точка: [-0.57701931 -0.57751568 -0.57751568], Норма: 1.0000
# Точка: [-0.57707664 -0.57748704 -0.57748704], Норма: 1.0000
# Точка: [-0.57712404 -0.57746335 -0.57746335], Норма: 1.0000
# Точка: [-0.57716323 -0.57744377 -0.57744377], Норма: 1.0000
# Точка: [-0.57719563 -0.57742758 -0.57742758], Норма: 1.0000
# Точка: [-0.57722241 -0.57741419 -0.57741419], Норма: 1.0000
# Точка: [-0.57724456 -0.57740312 -0.57740312], Норма: 1.0000
# Точка: [-0.57726287 -0.57739396 -0.57739396], Норма: 1.0000
# Точка: [-0.57727801 -0.5773864  -0.5773864 ], Норма: 1.0000
# Точка: [-0.57729052 -0.57738014 -0.57738014], Норма: 1.0000
# Точка: [-0.57730087 -0.57737497 -0.57737497], Норма: 1.0000
# Точка: [-0.57730943 -0.57737069 -0.57737069], Норма: 1.0000
# Точка: [-0.5773165  -0.57736715 -0.57736715], Норма: 1.0000
# Точка: [-0.57732235 -0.57736423 -0.57736423], Норма: 1.0000
# Точка: [-0.57732719 -0.57736181 -0.57736181], Норма: 1.0000
# Точка: [-0.57733118 -0.57735981 -0.57735981], Норма: 1.0000
# Точка: [-0.57733449 -0.57735816 -0.57735816], Норма: 1.0000
# Точка: [-0.57733722 -0.57735679 -0.57735679], Норма: 1.0000
# Точка: [-0.57733948 -0.57735566 -0.57735566], Норма: 1.0000
# Точка: [-0.57734135 -0.57735473 -0.57735473], Норма: 1.0000
# Точка: [-0.5773429  -0.57735396 -0.57735396], Норма: 1.0000
# Точка: [-0.57734417 -0.57735332 -0.57735332], Норма: 1.0000
# Точка: [-0.57734523 -0.57735279 -0.57735279], Норма: 1.0000
# Точка: [-0.5773461  -0.57735235 -0.57735235], Норма: 1.0000
# Точка: [-0.57734682 -0.57735199 -0.57735199], Норма: 1.0000
# Точка: [-0.57734742 -0.57735169 -0.57735169], Норма: 1.0000
# Точка: [-0.57734791 -0.57735145 -0.57735145], Норма: 1.0000
# Точка: [-0.57734832 -0.57735124 -0.57735124], Норма: 1.0000
# Точка: [-0.57734866 -0.57735107 -0.57735107], Норма: 1.0000
# Точка: [-0.57734894 -0.57735093 -0.57735093], Норма: 1.0000
# Точка: [-0.57734917 -0.57735082 -0.57735082], Норма: 1.0000
# Точка: [-0.57734936 -0.57735072 -0.57735072], Норма: 1.0000
# Точка: [-0.57734952 -0.57735065 -0.57735065], Норма: 1.0000
# Точка: [-0.57734965 -0.57735058 -0.57735058], Норма: 1.0000
# Точка: [-0.57734975 -0.57735053 -0.57735053], Норма: 1.0000
# Точка: [-0.57734984 -0.57735048 -0.57735048], Норма: 1.0000
# Точка: [-0.57734992 -0.57735044 -0.57735044], Норма: 1.0000
# Точка: [-0.57734998 -0.57735041 -0.57735041], Норма: 1.0000
# Точка: [-0.57735003 -0.57735039 -0.57735039], Норма: 1.0000
# Точка: [-0.57735007 -0.57735037 -0.57735037], Норма: 1.0000
# Точка: [-0.5773501  -0.57735035 -0.57735035], Норма: 1.0000
# Точка: [-0.57735013 -0.57735034 -0.57735034], Норма: 1.0000
# Точка: [-0.57735016 -0.57735033 -0.57735033], Норма: 1.0000
# Точка: [-0.57735018 -0.57735032 -0.57735032], Норма: 1.0000
# Точка: [-0.57735019 -0.57735031 -0.57735031], Норма: 1.0000
# Точка: [-0.57735021 -0.5773503  -0.5773503 ], Норма: 1.0000
# Точка: [-0.57735022 -0.5773503  -0.5773503 ], Норма: 1.0000
# Точка: [-0.57735023 -0.57735029 -0.57735029], Норма: 1.0000
# Точка: [-0.57735023 -0.57735029 -0.57735029], Норма: 1.0000
# Точка: [-0.57735024 -0.57735028 -0.57735028], Норма: 1.0000
# Точка: [-0.57735024 -0.57735028 -0.57735028], Норма: 1.0000
# Точка: [-0.57735025 -0.57735028 -0.57735028], Норма: 1.0000
# Оптимальная точка: [-0.57735025 -0.57735028 -0.57735028]
